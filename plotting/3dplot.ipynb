# %%
using Gaston, SpecialFunctions, DataFrames,DelimitedFiles

dat=transpose(readdlm("/home/planck/Desktop/secc_project_proposal/dats/dataset1_h2/sor_poisson2d_0.1_1_1.dat",' ',Float64,'\n'))
#x,y,z = dat[:1,:],dat[:2,:],
x=dat[:1,:]
y=dat[:2,:]
z=dat[:3,:]
#x = y = 0:0.075:10
surf(x, y, z, with = "pm3d",
     Axes(view = (45, 45),
          pm3d = "lighting primary 0.5 specular 0.4",
          key = :off)
     )
# Out:
# ┌ Warning: Gnuplot returned an error message:
# │     Warning: Single isoline (scan) is not enough for a pm3d plot.
# │ 	   Hint: Missing blank lines in the data file? See 'help pm3d' and FAQ.
# └ @ Gaston /home/planck/.julia/packages/Gaston/ctAQy/src/gaston_llplot.jl:182

# %%
surf(x, y, z, lc = :turquoise,
     Axes(title    = :Sombrero_Wireframe,
          hidden3d = :on))
